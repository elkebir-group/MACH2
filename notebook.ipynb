# %%
import mach2

# %%
tree = mach2.Phylogeny.from_file('data/mcpherson_2016/patient1.tree', 'data/mcpherson_2016/patient1.labeling')

# %%
tree

# %%
solver = mach2.MACH(tree, primary_site='LOv')
solutions = solver.solve('gurobi', 30, n_threads=30)
# Out:
# Set parameter MIPGap to value 0
# Set parameter PoolSolutions to value 30
# Set parameter PoolSearchMode to value 2
# Set parameter Threads to value 30

# %%
len(solutions)
# Out:
# 30

# %%
solutions.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/mroddur2/Current_Projects/MACH2/MACH2/notebook.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bada/home/mroddur2/Current_Projects/MACH2/MACH2/notebook.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> solutions.summary()
#
# File ~/Current_Projects/MACH2/MACH2/src/mach2/solutionset.py:78, in SolutionSet.summary(self, primary, colormap, colormap_file, consider_multi_edges, dot)
#      76 if colormap_file is None:
#      77     if self[0].colormap is None:
# ---> 78         colormap = utils.get_colormap(self.locations)
#      79     else:
#      80         colormap = self[0].colormap
#
# AttributeError: 'SolutionSet' object has no attribute 'locations'

# %%
solutions[0].migration_graph

# %%
solutions[0].phylogeny

# %%
from mach2viz import viz

# %%
v = viz.Viz(solution=solutions.json('test'))

# %%
v.run()
# Out:
#  * Serving Flask app 'mach2viz.viz'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [10/Nov/2023 12:12:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2023 12:12:01] "GET /mach2-viz/manifest.json HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2023 12:12:01] "GET /mach2-viz/static/css/main.d708e8a3.chunk.css HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2023 12:12:01] "GET /mach2-viz/static/js/2.49bf6ea5.chunk.js HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2023 12:12:01] "GET /mach2-viz/static/js/main.5a8e2600.chunk.js HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2023 12:12:03] "GET /json HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2023 12:12:03] "GET /mach2-viz/favicon.ico HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Nov/2023 12:12:08] "GET /mach2-viz/static/media/lucon.97a55c95.ttf HTTP/1.1" 200 -
# ...
